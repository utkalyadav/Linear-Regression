# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'], df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('cgpa')
plt.ylabel('package')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 3
#       1 plt.scatter(df['cgpa'], df['package'])
#       2 plt.plot(X_train,lr.predict(X_train),color='red')
# ----> 3 plt.xlabel('cgpa')
#       4 plt.ylabel('package')
#
# TypeError: 'str' object is not callable

# %%
X = df.iloc[:,0:1]
y= df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y , test_size =0.2, random_state =2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score

# %%
y_pred = lr.predict(X_test)

# %%
y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %%
print("MAE", mean_absolute_error(y_test, y_pred))
# Out:
# MAE 0.2884710931878175

# %%
print("MSE", mean_squared_error(y_test, y_pred))
# Out:
# MSE 0.12129235313495527

# %%
print("RMSE", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# RMSE 0.34827051717731616

# %%
print("r2 Score", r2_score(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
# Out:
# r2 Score 0.780730147510384

# %%
X_test.shape
# Out:
# (40, 1)

# %%
1- (1-r2)*(40-1)/(40-1-1)
# Out:
# 0.7749598882343415

# %%
new_df1 = df.copy()
new_df1['random_feature'] = np.random.random(200)

new_df1 = new_df1[['cgpa','random_feature','package']]

# %%
new_df1.head()
# Out:
#    cgpa  random_feature  package
# 0  6.89        0.258703     3.26
# 1  5.12        0.200789     1.98
# 2  7.82        0.585043     3.25
# 3  7.42        0.891856     3.67
# 4  6.94        0.787370     3.57

# %%
X = new_df1.iloc[:, 0:2]
y = new_df1.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state =2)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred= lr.predict(X_test)
y_pred
# Out:
# array([3.88735908, 3.09662044, 2.37618386, 2.57607925, 1.65520714,
#        1.77237191, 2.06294392, 2.92435719, 3.75445995, 2.93760535,
#        4.08383147, 3.5204575 , 2.96626839, 2.39555377, 3.19452677,
#        3.46473426, 1.95368925, 3.23458467, 2.96656797, 3.42071116,
#        2.55347967, 3.16624362, 2.85755256, 3.1168134 , 3.67874254,
#        2.87283344, 3.48563854, 3.34422616, 3.92485679, 1.95723326,
#        3.6490459 , 3.20920123, 3.73205921, 2.79559567, 2.771775  ,
#        3.26290281, 3.53479883, 2.61431802, 2.66313948, 2.72392221])

# %%
print("R2 score",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# R2 score 0.7808161331779734
